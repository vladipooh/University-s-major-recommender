# %%
#Read file from CSV

import pandas as pd
import numpy as np
df = pd.read_csv('import_data/TestingdataFull31-08-18Type.csv')
df
# Out:
#        sex    Age               major group3       year gpax     Region  \
# 0        f    >23           Business and Law      first    B  NorthEast
# 1        m    >23           Sciences & Maths      first   C+      North
# 2        f    >23                  Education     second    B      North
# 3        m  29-34      Engineer & Industrial  completed   B+      North
# 4        m  23-28                       ICTs  completed    B      North
# 5        m    >23      Engineer & Industrial     second   C+      North
# 6        f    >23           Sciences & Maths     second   B+    Central
# 7        m  29-34      Engineer & Industrial  completed    B      North
# 8        f    >23  Social sciences & Journal      third   B+      North
# 9        m    >23           Business and Law      third   B+      North
# 10       f    35+      Engineer & Industrial  completed   B+      North
# 11       f    >23      Engineer & Industrial      first   C+      North
# 12       f  29-34           Business and Law  completed    B  NorthEast
# 13       m    >23      Engineer & Industrial      forth    B    Central
# 14       m    35+           Business and Law  completed   C+  NorthEast
# 15       m  29-34                       ICTs  completed   C+  NorthEast
# 16       f    >23           Business and Law     second   B+      North
# 17       f    >23                  Education      third   B+      North
# 18       f    >23           Business and Law     second    B      North
# 19       f    >23                    Health      second    B      North
# 20       f    >23                    Health      second    B      North
# 21       f    >23                  Education     second   B+      North
# 22       m  23-28           Sciences & Maths      third    B      North
# 23       m    >23      Engineer & Industrial     second    B      North
# 24       f    >23      Engineer & Industrial      first   C+      North
# 25       m    >23           Sciences & Maths      third   C+      North
# 26       f  23-28           Sciences & Maths      forth    B      North
# 27       m    >23           Sciences & Maths     second   C+    Central
# 28       f    >23           Sciences & Maths     second    B       East
# 29       f    >23           Business and Law      third   C+      South
# ...    ...    ...                        ...        ...  ...        ...
# 1802     f    >23           Sciences & Maths      first    B    Central
# 1803     m  23-28           Sciences & Maths  completed    B       East
# 1804     f    >23           Sciences & Maths      forth    B    Central
# 1805     m  23-28           Sciences & Maths  completed    B      North
# 1806     m    >23           Sciences & Maths     second   B+       East
# 1807     f    >23           Sciences & Maths      third   C+      North
# 1808     m  23-28           Sciences & Maths  completed   C+  NorthEast
# 1809     m    >23           Sciences & Maths      forth   C+  NorthEast
# 1810     m    >23           Sciences & Maths      first   C+  NorthEast
# 1811     m    >23           Sciences & Maths      forth    B  NorthEast
# 1812     m    >23           Sciences & Maths     second   C+      North
# 1813     f    >23           Sciences & Maths      third   C+      North
# 1814     m    >23           Sciences & Maths     second   C+    Central
# 1815     m    >23           Sciences & Maths      third   C+      South
# 1816     f    >23           Sciences & Maths      first   C+    Central
# 1817     f    >23           Sciences & Maths      forth    B       East
# 1818     f  29-34           Sciences & Maths  completed   C+       East
# 1819     f    >23           Sciences & Maths      forth    B  NorthEast
# 1820     f    >23           Sciences & Maths     second   C+    Central
# 1821     f    >23           Sciences & Maths     second   C+       West
# 1822  LGBT  23-28           Sciences & Maths  completed   B+      North
# 1823     f    >23           Sciences & Maths      first    B      North
# 1824     f    >23           Sciences & Maths      first   C+    Central
# 1825  LGBT    >23           Sciences & Maths      first   B+    Central
# 1826     f  23-28           Sciences & Maths     second    B    Central
# 1827     f    >23           Sciences & Maths     second    B  NorthEast
# 1828     m    >23           Sciences & Maths      first   B+  NorthEast
# 1829     f  23-28           Sciences & Maths      first   C+  NorthEast
# 1830  LGBT    >23           Sciences & Maths      third    B      South
# 1831     f    >23           Sciences & Maths      first    B      South
#
#             previous-edu uni-activity influ-major influ-people  \
# 0     highschool-mathsci          yes         mid          low
# 1         highvocational          yes        high          mid
# 2         highschool-art          yes         mid          mid
# 3         highvocational          yes        high         high
# 4             vocational          yes        high          mid
# 5     highschool-mathsci           no         mid         high
# 6     highschool-mathsci          yes        high          mid
# 7     highschool-mathsci          yes        high          mid
# 8         highschool-art          yes        high          low
# 9             vocational          yes        high          mid
# 10    highschool-mathsci          yes        high          low
# 11            vocational          yes         mid         high
# 12    highschool-mathsci          yes         mid         high
# 13    highschool-mathsci          yes        high         high
# 14        highvocational          yes         mid          mid
# 15    highschool-mathsci          yes        high          mid
# 16            vocational          yes        high          low
# 17            vocational          yes        high         high
# 18    highschool-mathsci          yes         mid          mid
# 19            vocational           no         mid          mid
# 20            vocational           no         mid          mid
# 21            vocational           no         mid          mid
# 22        highvocational          yes        high          mid
# 23        highvocational          yes        high          mid
# 24            vocational          yes        high          mid
# 25            vocational          yes        high          mid
# 26    highschool-mathsci          yes        high          mid
# 27            vocational          yes        high          low
# 28    highschool-mathsci          yes        high         high
# 29        highvocational          yes        high          mid
# ...                  ...          ...         ...          ...
# 1802  highschool-mathsci          yes         mid          mid
# 1803      highschool-art           no        high          mid
# 1804      highschool-art          yes         mid          mid
# 1805  highschool-mathsci          yes         mid          mid
# 1806  highschool-mathsci          yes         mid          mid
# 1807  highschool-mathsci          yes         mid         high
# 1808  highschool-mathsci          yes         mid         high
# 1809  highschool-mathsci          yes         mid          low
# 1810      highschool-art          yes         mid         high
# 1811      highschool-art           no         mid          mid
# 1812      highvocational          yes        high          low
# 1813  highschool-mathsci          yes        high          mid
# 1814      highschool-art          yes         mid          mid
# 1815  highschool-mathsci          yes         mid          mid
# 1816      highschool-art          yes         mid          mid
# 1817      highschool-art          yes         mid          mid
# 1818      highschool-art          yes         mid         high
# 1819      highschool-art          yes         mid          mid
# 1820      highschool-art          yes         mid          mid
# 1821  highschool-mathsci          yes        high          mid
# 1822  highschool-mathsci          yes        high          low
# 1823  highschool-mathsci          yes         mid          mid
# 1824  highschool-mathsci          yes         mid         high
# 1825  highschool-mathsci          yes         low          mid
# 1826  highschool-mathsci           no        high          low
# 1827      highschool-art           no        high          low
# 1828  highschool-mathsci          yes        high         high
# 1829      highschool-art           no         mid         high
# 1830      highschool-art           no         low          low
# 1831      highschool-art           no         mid         high
#
#      influ-wellknown influ-quality influ-careermarket  TYPE
# 0                mid           mid                mid  ESFP
# 1                mid           mid               high  ENFJ
# 2               high           mid                mid  ESFJ
# 3               high           mid                mid  ENTJ
# 4               high          high                mid  ESFJ
# 5                mid           low                mid  INTJ
# 6                mid           mid               high  ESFJ
# 7               high          high               high  ESTJ
# 8                mid          high                mid  ISFJ
# 9                mid          high               high  ISFJ
# 10               mid           mid                mid  ESTP
# 11               mid           mid                low  ESFP
# 12              high           mid                mid  INTP
# 13              high          high               high  ESFJ
# 14               mid           mid                mid  ESTP
# 15              high           mid                mid  ISTP
# 16               mid          high               high  ESFJ
# 17               mid           mid               high  ESFP
# 18              high          high                mid  ENFP
# 19               mid           mid                mid  ENFP
# 20               mid           mid                mid  ENFP
# 21               mid          high                mid  ISFP
# 22               mid          high                mid  ESFJ
# 23               mid          high                mid  ESTJ
# 24               mid          high                mid  ESFJ
# 25               mid          high                mid  ESFJ
# 26               mid          high                mid  ESTJ
# 27              high           mid                mid  ENTJ
# 28              high           mid               high  ESTJ
# 29               mid          high               high  ESTJ
# ...              ...           ...                ...   ...
# 1802             mid           mid                mid  ESTP
# 1803             mid           low                mid  ISFP
# 1804             mid           mid                mid  ESTP
# 1805            high          high               high  ENTJ
# 1806            high           mid               high  ESFP
# 1807            high           mid               high  ENTJ
# 1808             mid           mid                mid  ESFP
# 1809            high           mid               high  ISFJ
# 1810             mid          high                mid  INFJ
# 1811             mid           mid                mid  ENTP
# 1812            high           mid                mid  INTJ
# 1813            high           mid               high  ESFJ
# 1814             mid           mid                mid  ENFJ
# 1815             mid           mid               high  ESTJ
# 1816            high          high                mid  ESFJ
# 1817             mid           mid                mid  ESTJ
# 1818            high           mid                mid  ESFJ
# 1819            high           mid                mid  ESFP
# 1820            high           mid                mid  ESFJ
# 1821             mid          high                mid  ESTJ
# 1822            high           mid                mid  INTJ
# 1823            high           mid               high  ESTJ
# 1824             mid           mid               high  ENTJ
# 1825            high           mid                mid  ISFJ
# 1826            high          high               high  ESTP
# 1827             low          high                mid  ESFP
# 1828            high          high                mid  ESTJ
# 1829             mid          high                mid  ISTJ
# 1830            high           mid                low  ENTP
# 1831             mid           low                low  ENTP
#
# [1832 rows x 14 columns]

# %%
#function transform nominal to numeric multicoloumn

from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# Create some toy data in a Pandas dataframe
fruit_data = pd.DataFrame({
    'fruit':  ['apple','orange','pear','orange'],
    'color':  ['red','orange','green','green'],
    'weight': [5,6,3,4]
})

class MultiColumnLabelEncoder:
    def __init__(self,columns = None):
        self.columns = columns # array of column names to encode

    def fit(self,X,y=None):
        return self # not relevant here

    def transform(self,X):
        '''
        Transforms columns of X specified in self.columns using
        LabelEncoder(). If no columns specified, transforms all
        columns in X.
        '''
        output = X.copy()
        if self.columns is not None:
            for col in self.columns:
                output[col] = LabelEncoder().fit_transform(output[col])
        else:
            for colname,col in output.iteritems():
                output[colname] = LabelEncoder().fit_transform(col)
        return output

    def fit_transform(self,X,y=None):
        return self.fit(X,y).transform(X)

# %%
#Call fn transform

df = MultiColumnLabelEncoder(columns = ['sex','Age','major group3','year','gpax','Region','previous-edu','uni-activity','influ-major','influ-people','influ-wellknown','influ-quality','influ-careermarket','TYPE']).fit_transform(df)

# %%
# split label column

result = df['major group3']
dfwithoutlabel = df.drop(['major group3'], axis=1)

# %%
# split data to 8:2 training to testing

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(dfwithoutlabel, result, test_size=0.2, random_state=42)

# %%
# train data with XGBoost

from sklearn.datasets import make_hastie_10_2
from sklearn.ensemble import GradientBoostingClassifier

clf = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1,max_depth=5, random_state=99).fit(X_train, y_train)

# %%
# Accuracy in percentage

(clf.score(X_test, y_test))*100
# Out:
# 86.10354223433242

# %%
# save model

import pickle

#serializing our model to a file called model.pkl
pickle.dump(clf, open("export_data/mbti.pkl","wb"))

#loading a model from a file called model.pkl
model = pickle.load(open("export_data/mbti.pkl","rb"))

# %%
# test prediction

clf.predict([[1,3,1,1,3,2,1,2,1,2,2,2,5]])
# Out:
# array([1])

# %%
result
# Out:
# 0       1
# 1       6
# 2       2
# 3       3
# 4       5
# 5       3
# 6       6
# 7       3
# 8       7
# 9       1
# 10      3
# 11      3
# 12      1
# 13      3
# 14      1
# 15      5
# 16      1
# 17      2
# 18      1
# 19      4
# 20      4
# 21      2
# 22      6
# 23      3
# 24      3
# 25      6
# 26      6
# 27      6
# 28      6
# 29      1
#        ..
# 1802    6
# 1803    6
# 1804    6
# 1805    6
# 1806    6
# 1807    6
# 1808    6
# 1809    6
# 1810    6
# 1811    6
# 1812    6
# 1813    6
# 1814    6
# 1815    6
# 1816    6
# 1817    6
# 1818    6
# 1819    6
# 1820    6
# 1821    6
# 1822    6
# 1823    6
# 1824    6
# 1825    6
# 1826    6
# 1827    6
# 1828    6
# 1829    6
# 1830    6
# 1831    6
# Name: major group3, dtype: int64
